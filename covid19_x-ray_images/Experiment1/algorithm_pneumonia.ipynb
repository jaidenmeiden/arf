# %% [markdown]
# # Creating Dataset

# %% [markdown]
# Desarrollar un clasificador de Rayos X de tórax Covid-19, Normal y Neumonía, como un clasificador multiclase con VGG16 y tensorflow.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import VGG16
from keras.layers import AveragePooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import shutil
import random
import cv2
import argparse
import os

# %%
device_name = tf.test.gpu_device_name()
if "GPU" not in device_name:
    print("GPU device not found")
print('Found GPU at: {}'.format(device_name))

plt.rcParams['figure.figsize'] = [8.0, 8.0]
plt.rcParams['figure.dpi'] = 100
# Out:
# GPU device not found
# Found GPU at:

# %%
dataset_path = './dataset'

# %%
# %%bash
# rm -rf dataset
# mkdir -p dataset/covid
# mkdir -p dataset/normal
# mkdir -p dataset/pneumonia
# mkdir -p dataset/new

# %%
covid_19_path = "../DataSet1/covid-chest-xray"
pneumonia_dataset_path ='../DataSet1/chest-xray-pneumonia/chest_xray'

# %% [markdown]
# ## EDA of COVID Data Set

# %%
eda = pd.read_csv('../DataSet1/covid-chest-xray/metadata.csv')

# %%
eda.head()

# %%
sns.countplot(x = 'finding', data = eda, palette = 'husl')
plt.xticks(rotation=60)
plt.savefig("Count_vs_Finding.png")
plt.show()

# %%
sns.countplot(x = 'sex', data = eda, palette = 'husl')
plt.xticks(rotation=60)
plt.savefig("Count_vs_Sex.png")
plt.show()
# Out:
#    patientid  offset sex   age   finding survival intubated  \
# 0          2     0.0   M  65.0  COVID-19        Y       NaN
# 1          2     3.0   M  65.0  COVID-19        Y       NaN
# 2          2     5.0   M  65.0  COVID-19        Y       NaN
# 3          2     6.0   M  65.0  COVID-19        Y       NaN
# 4          4     0.0   F  52.0  COVID-19      NaN       NaN
#
#   intubation_present went_icu in_icu  ...              date  \
# 0                NaN      NaN    NaN  ...  January 22, 2020
# 1                NaN      NaN    NaN  ...  January 25, 2020
# 2                NaN      NaN    NaN  ...  January 27, 2020
# 3                NaN      NaN    NaN  ...  January 28, 2020
# 4                NaN      NaN    NaN  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Ta...  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes Unnamed: 28
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 1  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 2  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 3  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 4   diffuse infiltrates in the bilateral lower lungs         NaN         NaN
#
# [5 rows x 29 columns]

# %%
sns.countplot(x = 'finding', data = eda, palette = 'husl')
plt.xticks(rotation=60)
plt.savefig("Count_vs_Finding.png")
plt.show()

# %%
sns.countplot(x = 'sex', data = eda, palette = 'husl')
plt.xticks(rotation=60)
plt.savefig("Count_vs_Sex.png")
plt.show()

# %% [markdown]
# # Creating Dataset

# %%
# construct the path to the metadata CSV file and load it
csvPath = os.path.sep.join([covid_19_path, "metadata.csv"])
df = pd.read_csv(csvPath)

# loop over the rows of the COVID-19 data frame
for (i, row) in df.iterrows():
    # if (1) the current case is not COVID-19 or (2) this is not
    # a 'PA' view, then ignore the row
    if row["finding"] != "COVID-19" or row["view"] != "PA":
        continue

    # build the path to the input image file
    imagePath = os.path.sep.join([covid_19_path, "images", row["filename"]])

    # if the input image file does not exist (there are some errors in
    # the COVID-19 metadeta file), ignore the row
    if not os.path.exists(imagePath):
        continue

    # extract the filename from the image path and then construct the
    # path to the copied image file
    filename = row["filename"].split(os.path.sep)[-1]
    outputPath = os.path.sep.join([f"{dataset_path}/covid", filename])

    # copy the image
    shutil.copy2(imagePath, outputPath)

# %%
basePath = os.path.sep.join([pneumonia_dataset_path, "train", "NORMAL"])
imagePaths = list(paths.list_images(basePath))
samples = 146

# randomly sample the image paths
random.seed(42)
random.shuffle(imagePaths)
imagePaths = imagePaths[:samples]

# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
    # extract the filename from the image path and then construct the
    # path to the copied image file
    filename = imagePath.split(os.path.sep)[-1]
    outputPath = os.path.sep.join([f"{dataset_path}/normal", filename])

    # copy the image
    shutil.copy2(imagePath, outputPath)

# %%
basePath = os.path.sep.join([pneumonia_dataset_path, "train", "PNEUMONIA"])
imagePaths = list(paths.list_images(basePath))
samples = 146

# randomly sample the image paths
random.seed(42)
random.shuffle(imagePaths)
imagePaths = imagePaths[:samples]

# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
    # extract the filename from the image path and then construct the
    # path to the copied image file
    filename = imagePath.split(os.path.sep)[-1]
    outputPath = os.path.sep.join([f"{dataset_path}/pneumonia", filename])

    # copy the image
    shutil.copy2(imagePath, outputPath)

# %% [markdown]
# # X-ray show

# %%
def ceildiv(a, b):
    return -(-a // b)

def plots_from_files(imspaths, figsize=(10,5), rows=1, titles=None, maintitle=None):
    """Plot the images in a grid"""
    f = plt.figure(figsize=figsize)
    if maintitle is not None: plt.suptitle(maintitle, fontsize=10)
    for i in range(len(imspaths)):
        sp = f.add_subplot(rows, ceildiv(len(imspaths), rows), i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=16)
        img = plt.imread(imspaths[i])
        plt.imshow(img)
    plt.savefig(maintitle.replace(" ", "_") + ".png")

normal_images = list(paths.list_images(f"{dataset_path}/normal"))
covid_images = list(paths.list_images(f"{dataset_path}/covid"))
pneumonia_images = list(paths.list_images(f"{dataset_path}/pneumonia"))

# %%
plots_from_files(normal_images, rows=5, maintitle="Normal X-ray images")

# %%
plots_from_files(covid_images, rows=5, maintitle="Covid-19 X-ray images")

# %%
plots_from_files(pneumonia_images, rows=5, maintitle="Pneumonia X-ray images")

# %% [markdown]
# # Data Preprocesing

# %%
# initialize the initial learning rate, number of epochs to train for,
# and batch size
INIT_LR = 1e-3
EPOCHS = 100
BS = 8

# %%
# lets take the labels of each image in the directory to make a classfication
print("[INFO] loading images...")
imagePaths = list(paths.list_images(dataset_path))
data = []
labels = []
# loop over the image paths
for imagePath in imagePaths:
    # extract the class label from the filename
    label = imagePath.split(os.path.sep)[-2]
    # load the image, swap color channels, and resize it to be a fixed
    # 224x224 pixels while ignoring aspect ratio
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))
    # update the data and labels lists, respectively
    data.append(image)
    labels.append(label)
# convert the data and labels to NumPy arrays while scaling the pixel
# intensities to the range [0, 1]
data = np.array(data) / 255.0
labels = np.array(labels)
print("[INFO] Images successfully loaded")
# Out:
# [INFO] loading images...
# [INFO] Images successfully loaded

# %%
# Now we will create a One-Hot encoding to the list of labels to make the classfication
# integer encode
lb_encoder = LabelEncoder()
labels = lb_encoder.fit_transform(labels)
labels = to_categorical(labels)


# Split the data into training and testing using the 80% of training and 20% to testing
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size = 0.2, stratify = labels,random_state = 42)


# Set the image augmentation of the training data
trainAug = ImageDataGenerator(rotation_range= 15, fill_mode='nearest')

# %% [markdown]
# # Making the model VGG16

# %%
base_model = VGG16(weights = 'imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)))
headmodel = base_model.output
headmodel = AveragePooling2D(pool_size =(4, 4))(headmodel)
headmodel = Flatten(name ='Flatten')(headmodel)
headmodel = Dense(64, activation = 'relu')(headmodel)
headmodel = Dropout(0.5)(headmodel)
headmodel = Dense(3, activation = 'softmax')(headmodel)

model = Model(inputs = base_model.input, outputs = headmodel)

for layers in base_model.layers:
    layers.trainable = False


opt = Adam(lr = INIT_LR, decay = INIT_LR/EPOCHS)
model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 14,747,715
# Trainable params: 33,027
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# training the model with gpu or cpu, it depends:

with tf.device('/gpu:0'):
    print("Training the model with gpu . . .")
    training = model.fit_generator(trainAug.flow(X_train, y_train, batch_size = BS),steps_per_epoch=len(X_train) // BS, validation_data=(X_test, y_test), validation_steps=len(X_test) // BS, epochs=100)

#with tf.device('/cpu:0'):
#    print("Training the model with cpu . . .")
#    training = model.fit_generator(trainAug.flow(X_train, y_train, batch_size = BS),steps_per_epoch=len(X_train) // BS, validation_data=(X_test, y_test), validation_steps=len(X_test) // BS, epochs=100)
# Out:
# Training the model with gpu . . .
# /home/oem/Desarrollo/Master/Homework/arf/covid19_x-ray_images/venv/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 43/43 [==============================] - 39s 909ms/step - loss: 0.6951 - accuracy: 0.3834 - val_loss: 0.5705 - val_accuracy: 0.6552
# Epoch 2/100
# 43/43 [==============================] - 31s 727ms/step - loss: 0.5620 - accuracy: 0.6286 - val_loss: 0.5366 - val_accuracy: 0.5287
# Epoch 3/100
# 43/43 [==============================] - 33s 781ms/step - loss: 0.5377 - accuracy: 0.6200 - val_loss: 0.4776 - val_accuracy: 0.7586
# Epoch 4/100
# 43/43 [==============================] - 34s 792ms/step - loss: 0.4669 - accuracy: 0.7733 - val_loss: 0.4460 - val_accuracy: 0.7586
# Epoch 5/100
# 43/43 [==============================] - 31s 733ms/step - loss: 0.4135 - accuracy: 0.8308 - val_loss: 0.4230 - val_accuracy: 0.7356
# Epoch 6/100
# 43/43 [==============================] - 31s 720ms/step - loss: 0.3883 - accuracy: 0.8190 - val_loss: 0.3960 - val_accuracy: 0.7701
# Epoch 7/100
# 43/43 [==============================] - 32s 744ms/step - loss: 0.3634 - accuracy: 0.8396 - val_loss: 0.3741 - val_accuracy: 0.7701
# Epoch 8/100
# 43/43 [==============================] - 33s 781ms/step - loss: 0.3476 - accuracy: 0.8497 - val_loss: 0.3565 - val_accuracy: 0.7471
# Epoch 9/100
# 43/43 [==============================] - 36s 833ms/step - loss: 0.3106 - accuracy: 0.8825 - val_loss: 0.3477 - val_accuracy: 0.7701
# Epoch 10/100
# 43/43 [==============================] - 31s 731ms/step - loss: 0.3185 - accuracy: 0.8599 - val_loss: 0.3411 - val_accuracy: 0.7701
# Epoch 11/100
# 43/43 [==============================] - 30s 712ms/step - loss: 0.2837 - accuracy: 0.9019 - val_loss: 0.3416 - val_accuracy: 0.7816
# Epoch 12/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.2894 - accuracy: 0.8600 - val_loss: 0.3200 - val_accuracy: 0.7816
# Epoch 13/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.2842 - accuracy: 0.8524 - val_loss: 0.3051 - val_accuracy: 0.7931
# Epoch 14/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.2304 - accuracy: 0.9148 - val_loss: 0.2933 - val_accuracy: 0.8046
# Epoch 15/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.2312 - accuracy: 0.8996 - val_loss: 0.2903 - val_accuracy: 0.8276
# Epoch 16/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.2206 - accuracy: 0.9383 - val_loss: 0.2846 - val_accuracy: 0.8046
# Epoch 17/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.2105 - accuracy: 0.9120 - val_loss: 0.2987 - val_accuracy: 0.7931
# Epoch 18/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.2123 - accuracy: 0.8973 - val_loss: 0.2851 - val_accuracy: 0.8161
# Epoch 19/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.2453 - accuracy: 0.8970 - val_loss: 0.2688 - val_accuracy: 0.8046
# Epoch 20/100
# 43/43 [==============================] - 30s 694ms/step - loss: 0.1900 - accuracy: 0.9134 - val_loss: 0.2640 - val_accuracy: 0.8161
# Epoch 21/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.1886 - accuracy: 0.8999 - val_loss: 0.2521 - val_accuracy: 0.8161
# Epoch 22/100
# 43/43 [==============================] - 30s 698ms/step - loss: 0.1933 - accuracy: 0.9353 - val_loss: 0.2523 - val_accuracy: 0.8391
# Epoch 23/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.1773 - accuracy: 0.9245 - val_loss: 0.2427 - val_accuracy: 0.8276
# Epoch 24/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.1807 - accuracy: 0.9014 - val_loss: 0.2466 - val_accuracy: 0.8391
# Epoch 25/100
# 43/43 [==============================] - 30s 700ms/step - loss: 0.1823 - accuracy: 0.9239 - val_loss: 0.2333 - val_accuracy: 0.8276
# Epoch 26/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.1543 - accuracy: 0.9475 - val_loss: 0.2353 - val_accuracy: 0.8276
# Epoch 27/100
# 43/43 [==============================] - 30s 698ms/step - loss: 0.1543 - accuracy: 0.9438 - val_loss: 0.2317 - val_accuracy: 0.8506
# Epoch 28/100
# 43/43 [==============================] - 31s 723ms/step - loss: 0.1758 - accuracy: 0.9378 - val_loss: 0.2288 - val_accuracy: 0.8391
# Epoch 29/100
# 43/43 [==============================] - 34s 804ms/step - loss: 0.1612 - accuracy: 0.9263 - val_loss: 0.2527 - val_accuracy: 0.8506
# Epoch 30/100
# 43/43 [==============================] - 39s 895ms/step - loss: 0.1506 - accuracy: 0.9347 - val_loss: 0.2265 - val_accuracy: 0.8391
# Epoch 31/100
# 43/43 [==============================] - 32s 734ms/step - loss: 0.1501 - accuracy: 0.9575 - val_loss: 0.2112 - val_accuracy: 0.8621
# Epoch 32/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.1419 - accuracy: 0.9302 - val_loss: 0.2173 - val_accuracy: 0.8391
# Epoch 33/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.1473 - accuracy: 0.9149 - val_loss: 0.2366 - val_accuracy: 0.8391
# Epoch 34/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.1336 - accuracy: 0.9655 - val_loss: 0.2468 - val_accuracy: 0.8506
# Epoch 35/100
# 43/43 [==============================] - 30s 709ms/step - loss: 0.1389 - accuracy: 0.9483 - val_loss: 0.2156 - val_accuracy: 0.8506
# Epoch 36/100
# 43/43 [==============================] - 31s 708ms/step - loss: 0.1269 - accuracy: 0.9538 - val_loss: 0.2120 - val_accuracy: 0.8736
# Epoch 37/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.1294 - accuracy: 0.9262 - val_loss: 0.2103 - val_accuracy: 0.8736
# Epoch 38/100
# 43/43 [==============================] - 33s 771ms/step - loss: 0.1219 - accuracy: 0.9428 - val_loss: 0.2323 - val_accuracy: 0.8851
# Epoch 39/100
# 43/43 [==============================] - 30s 707ms/step - loss: 0.1423 - accuracy: 0.9315 - val_loss: 0.2143 - val_accuracy: 0.8621
# Epoch 40/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.1135 - accuracy: 0.9609 - val_loss: 0.2181 - val_accuracy: 0.8851
# Epoch 41/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.1208 - accuracy: 0.9414 - val_loss: 0.2438 - val_accuracy: 0.8621
# Epoch 42/100
# 43/43 [==============================] - 30s 717ms/step - loss: 0.1285 - accuracy: 0.9316 - val_loss: 0.2419 - val_accuracy: 0.8621
# Epoch 43/100
# 43/43 [==============================] - 31s 717ms/step - loss: 0.1104 - accuracy: 0.9491 - val_loss: 0.2238 - val_accuracy: 0.8851
# Epoch 44/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.1093 - accuracy: 0.9537 - val_loss: 0.2292 - val_accuracy: 0.8736
# Epoch 45/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0976 - accuracy: 0.9734 - val_loss: 0.2084 - val_accuracy: 0.8621
# Epoch 46/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.1240 - accuracy: 0.9412 - val_loss: 0.2272 - val_accuracy: 0.8736
# Epoch 47/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.1266 - accuracy: 0.9345 - val_loss: 0.2128 - val_accuracy: 0.8966
# Epoch 48/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.1010 - accuracy: 0.9541 - val_loss: 0.2276 - val_accuracy: 0.8851
# Epoch 49/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.1020 - accuracy: 0.9519 - val_loss: 0.2291 - val_accuracy: 0.8506
# Epoch 50/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0905 - accuracy: 0.9717 - val_loss: 0.2216 - val_accuracy: 0.8851
# Epoch 51/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0872 - accuracy: 0.9555 - val_loss: 0.1913 - val_accuracy: 0.8736
# Epoch 52/100
# 43/43 [==============================] - 31s 716ms/step - loss: 0.0903 - accuracy: 0.9604 - val_loss: 0.2458 - val_accuracy: 0.8736
# Epoch 53/100
# 43/43 [==============================] - 31s 713ms/step - loss: 0.0845 - accuracy: 0.9615 - val_loss: 0.1915 - val_accuracy: 0.8736
# Epoch 54/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.0769 - accuracy: 0.9657 - val_loss: 0.2157 - val_accuracy: 0.8851
# Epoch 55/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.1100 - accuracy: 0.9422 - val_loss: 0.2016 - val_accuracy: 0.8851
# Epoch 56/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0921 - accuracy: 0.9567 - val_loss: 0.2168 - val_accuracy: 0.8966
# Epoch 57/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.1050 - accuracy: 0.9450 - val_loss: 0.2018 - val_accuracy: 0.8851
# Epoch 58/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0863 - accuracy: 0.9561 - val_loss: 0.2393 - val_accuracy: 0.8736
# Epoch 59/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0735 - accuracy: 0.9747 - val_loss: 0.2380 - val_accuracy: 0.8736
# Epoch 60/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.0729 - accuracy: 0.9754 - val_loss: 0.2254 - val_accuracy: 0.8736
# Epoch 61/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.0847 - accuracy: 0.9576 - val_loss: 0.2410 - val_accuracy: 0.8736
# Epoch 62/100
# 43/43 [==============================] - 30s 707ms/step - loss: 0.0818 - accuracy: 0.9698 - val_loss: 0.1946 - val_accuracy: 0.8851
# Epoch 63/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.0896 - accuracy: 0.9608 - val_loss: 0.2109 - val_accuracy: 0.8851
# Epoch 64/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.1022 - accuracy: 0.9325 - val_loss: 0.2543 - val_accuracy: 0.8851
# Epoch 65/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0839 - accuracy: 0.9599 - val_loss: 0.1831 - val_accuracy: 0.8851
# Epoch 66/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0980 - accuracy: 0.9580 - val_loss: 0.2175 - val_accuracy: 0.8736
# Epoch 67/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0797 - accuracy: 0.9793 - val_loss: 0.2229 - val_accuracy: 0.8736
# Epoch 68/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.1096 - accuracy: 0.9492 - val_loss: 0.2514 - val_accuracy: 0.8966
# Epoch 69/100
# 43/43 [==============================] - 30s 698ms/step - loss: 0.1143 - accuracy: 0.9160 - val_loss: 0.2335 - val_accuracy: 0.8851
# Epoch 70/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0668 - accuracy: 0.9674 - val_loss: 0.2188 - val_accuracy: 0.8851
# Epoch 71/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.0823 - accuracy: 0.9611 - val_loss: 0.2087 - val_accuracy: 0.8851
# Epoch 72/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.0465 - accuracy: 0.9916 - val_loss: 0.2581 - val_accuracy: 0.8851
# Epoch 73/100
# 43/43 [==============================] - 30s 698ms/step - loss: 0.0582 - accuracy: 0.9781 - val_loss: 0.2430 - val_accuracy: 0.8851
# Epoch 74/100
# 43/43 [==============================] - 30s 698ms/step - loss: 0.0684 - accuracy: 0.9867 - val_loss: 0.2087 - val_accuracy: 0.8736
# Epoch 75/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.0847 - accuracy: 0.9593 - val_loss: 0.2168 - val_accuracy: 0.8851
# Epoch 76/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0851 - accuracy: 0.9595 - val_loss: 0.1935 - val_accuracy: 0.8966
# Epoch 77/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.0885 - accuracy: 0.9628 - val_loss: 0.1991 - val_accuracy: 0.8736
# Epoch 78/100
# 43/43 [==============================] - 31s 725ms/step - loss: 0.0732 - accuracy: 0.9754 - val_loss: 0.2105 - val_accuracy: 0.8851
# Epoch 79/100
# 43/43 [==============================] - 33s 773ms/step - loss: 0.0746 - accuracy: 0.9802 - val_loss: 0.2338 - val_accuracy: 0.8851
# Epoch 80/100
# 43/43 [==============================] - 35s 828ms/step - loss: 0.0594 - accuracy: 0.9882 - val_loss: 0.2036 - val_accuracy: 0.8851
# Epoch 81/100
# 43/43 [==============================] - 35s 805ms/step - loss: 0.0556 - accuracy: 0.9888 - val_loss: 0.2303 - val_accuracy: 0.8851
# Epoch 82/100
# 43/43 [==============================] - 38s 889ms/step - loss: 0.0773 - accuracy: 0.9637 - val_loss: 0.2546 - val_accuracy: 0.8851
# Epoch 83/100
# 43/43 [==============================] - 31s 712ms/step - loss: 0.0709 - accuracy: 0.9705 - val_loss: 0.2144 - val_accuracy: 0.8851
# Epoch 84/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0780 - accuracy: 0.9629 - val_loss: 0.2100 - val_accuracy: 0.8966
# Epoch 85/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0658 - accuracy: 0.9655 - val_loss: 0.3103 - val_accuracy: 0.8966
# Epoch 86/100
# 43/43 [==============================] - 30s 710ms/step - loss: 0.0501 - accuracy: 0.9900 - val_loss: 0.2602 - val_accuracy: 0.8966
# Epoch 87/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.0541 - accuracy: 0.9882 - val_loss: 0.2295 - val_accuracy: 0.8966
# Epoch 88/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.0550 - accuracy: 0.9901 - val_loss: 0.2214 - val_accuracy: 0.8851
# Epoch 89/100
# 43/43 [==============================] - 30s 707ms/step - loss: 0.0676 - accuracy: 0.9691 - val_loss: 0.2212 - val_accuracy: 0.8736
# Epoch 90/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0392 - accuracy: 0.9899 - val_loss: 0.2246 - val_accuracy: 0.8966
# Epoch 91/100
# 43/43 [==============================] - 30s 708ms/step - loss: 0.0582 - accuracy: 0.9745 - val_loss: 0.2725 - val_accuracy: 0.8736
# Epoch 92/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.0754 - accuracy: 0.9729 - val_loss: 0.2362 - val_accuracy: 0.8966
# Epoch 93/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.0516 - accuracy: 0.9790 - val_loss: 0.2284 - val_accuracy: 0.8851
# Epoch 94/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.0578 - accuracy: 0.9727 - val_loss: 0.2236 - val_accuracy: 0.8736
# Epoch 95/100
# 43/43 [==============================] - 30s 705ms/step - loss: 0.0413 - accuracy: 0.9892 - val_loss: 0.2322 - val_accuracy: 0.8736
# Epoch 96/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0460 - accuracy: 0.9851 - val_loss: 0.2531 - val_accuracy: 0.8851
# Epoch 97/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0527 - accuracy: 0.9906 - val_loss: 0.2575 - val_accuracy: 0.8851
# Epoch 98/100
# 43/43 [==============================] - 30s 711ms/step - loss: 0.0515 - accuracy: 0.9812 - val_loss: 0.2735 - val_accuracy: 0.8966
# Epoch 99/100
# 43/43 [==============================] - 30s 719ms/step - loss: 0.0548 - accuracy: 0.9819 - val_loss: 0.2655 - val_accuracy: 0.8851
# Epoch 100/100
# 43/43 [==============================] - 30s 706ms/step - loss: 0.0489 - accuracy: 0.9966 - val_loss: 0.2562 - val_accuracy: 0.8966

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use('ggplot')
plt.figure()
plt.plot(np.arange(0, N), training.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), training.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), training.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for Classification between COVID-19/Pneumonia/Normal")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right", bbox_to_anchor=(1.25, 1))
plt.savefig("Loss_and_Accuracy.png")

# %% [markdown]
# ## Save model

# %%
model.save("VGG16_Covid19_Normal_Neumonia.h5")

# %% [markdown]
# # Evaluting the model

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(X_test, batch_size=BS)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)
# show a nicely formatted classification report
print(classification_report(y_test.argmax(axis=1), predIdxs, target_names=lb_encoder.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#        covid       0.93      1.00      0.97        28
#       normal       0.82      0.97      0.89        29
#    pneumonia       0.96      0.73      0.83        30
#
#     accuracy                           0.90        87
#    macro avg       0.90      0.90      0.89        87
# weighted avg       0.90      0.90      0.89        87

# %%
# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
cm = confusion_matrix(y_test.argmax(axis=1), predIdxs)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# show the accuracy, sensitivity, and specificity of the test
print("accuracy: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# accuracy: 0.6437
# sensitivity: 1.0000
# specificity: 1.0000

# %%
df_cm= pd.DataFrame(cm, columns=lb_encoder.classes_, index=lb_encoder.classes_)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sns.heatmap(df_cm/np.sum(df_cm), fmt='.2%', annot = True, annot_kws={'size':16})
plt.savefig("Actual_vs_Predicted.png")
plt.show()

# %%
rows = 10
columns = 9
fig = plt.figure(figsize=(20, 20))
for m in range(1, 88):
    if str(lb_encoder.inverse_transform(predIdxs)[m-1]) == "covid":
        text = "COVID"
        color = (0, 255, 0)
    elif str(lb_encoder.inverse_transform(predIdxs)[m-1]) == "normal":
        text = "Normal"
        color = (255, 0, 0)
    elif str(lb_encoder.inverse_transform(predIdxs)[m-1]) == "pneumonia":
        text = "Pneumonia"
        color = (0, 0, 255)
        
    if str(lb_encoder.inverse_transform(y_test.argmax(axis=1))[m-1]) == "covid":
        text2 = "COVID"
        color2 = (0, 255, 0)
    elif str(lb_encoder.inverse_transform(y_test.argmax(axis=1))[m-1]) == "normal":
        text2 = "Normal"
        color2 = (255, 0, 0)
    elif str(lb_encoder.inverse_transform(y_test.argmax(axis=1))[m-1]) == "pneumonia":
        text2 = "Pneumonia"
        color2 = (0, 0, 255)
    img = X_test[m-1].copy()
    # Window name in which image is displayed 
    window_name = text
  
    # font 
    font = cv2.FONT_HERSHEY_SIMPLEX 
  
    # org 
    org = (50, 50) 
  
    # fontScale 
    fontScale = 1
  
    # Line thickness of 2 px 
    thickness = 2
    img = cv2.putText(img, text, org, font,
                      fontScale, color, thickness, cv2.LINE_AA)
    fig.add_subplot(rows, columns, m)
    plt.imshow(img)
    plt.title("Actual: " + text2)
    plt.axis('off')
    if m == 87:
        plt.savefig("./Results1.png")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Trying with new images in different database ("covid19-radiography-database")

# %%
new_dataset ='../DataSet1/covid19-radiography-database/COVID-19_Radiography_Dataset'

# %%
basePath = os.path.sep.join([new_dataset, "ViralPneumonia"])
imagePaths = list(paths.list_images(basePath))
samples = 3

# randomly sample the image paths
random.seed(42)
random.shuffle(imagePaths)
imagePaths = imagePaths[:samples]

# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
    # extract the filename from the image path and then construct the
    # path to the copied image file
    filename = imagePath.split(os.path.sep)[-1]
    outputPath = os.path.sep.join([f"{dataset_path}/new", filename])

    # copy the image
    shutil.copy2(imagePath, outputPath)

new_images = list(paths.list_images(f"{dataset_path}/new"))
plots_from_files(new_images, rows=3, maintitle="New X-ray images")

# %%
new_data = []
for imagePath in imagePaths:
    new_image = cv2.imread(imagePath)
    new_image = cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB)
    new_image = cv2.resize(new_image, (224, 224))
    # update the data and labels lists, respectively
    new_data.append(new_image)

new_data = np.array(new_data) / 255.0
new_data.shape
# Out:
# (3, 224, 224, 3)

# %%
# make new predictions:
print("[INFO] Making new predictions...")
new_pred = model.predict(new_data, batch_size=BS)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
new_pred = np.argmax(new_pred, axis=1)
# Out:
# [INFO] Making new predictions...

# %%
print("[INFO] printing new images with their classification")
rows = 1
columns = 3
fig = plt.figure(figsize=(20, 20))
for m in range(1, 4):
    if str(lb_encoder.inverse_transform(new_pred)[m-1]) == "covid":
        text = "COVID"
        color = (0, 255, 0)
    elif str(lb_encoder.inverse_transform(new_pred)[m-1]) == "normal":
        text = "Normal"
        color = (255, 0, 0)
    elif str(lb_encoder.inverse_transform(new_pred)[m-1]) == "pneumonia":
        text = "Pneumonia"
        color = (0, 0, 255)
    img = X_test[m-1].copy()
    # Window name in which image is displayed 
    window_name = text
  
    # font 
    font = cv2.FONT_HERSHEY_SIMPLEX 
  
    # org 
    org = (50, 50) 
  
    # fontScale 
    fontScale = 1
  
    # Line thickness of 2 px 
    thickness = 2
    img = cv2.putText(img, text, org, font,
                      fontScale, color, thickness, cv2.LINE_AA)
    fig.add_subplot(rows, columns, m)
    plt.imshow(img)
    plt.axis('off')
    if m == 3:
        plt.savefig("./Results2.png")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [INFO] printing new images with their classification

# %%
new_data2 = []

# Making some new testing for a specific image in the file:
new_imag2 = cv2.imread('../DataSet1/covid19-radiography-database/COVID-19_Radiography_Dataset/COVID/COVID-19.png')
new_imag2 = cv2.cvtColor(new_imag2, cv2.COLOR_BGR2RGB)
new_imag2 = cv2.resize(new_imag2, (224,224))
new_data2.append(new_imag2)

new_data2 = np.array(new_data2)/255.0

# make new prediction
print("[INFO] Making new prediction...")
new_pred2 = model.predict(new_data2, batch_size=BS)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
new_pred2 = np.argmax(new_pred2, axis=1)

print("[INFO] printing new image with its classification")
rows = 1
columns = 3
fig = plt.figure(figsize=(20, 20))
for m in range(1, 2):
    if str(lb_encoder.inverse_transform(new_pred2)[m-1]) == "covid":
        text = "COVID"
        color = (0, 255, 0)
    elif str(lb_encoder.inverse_transform(new_pred2)[m-1]) == "normal":
        text = "Normal"
        color = (255, 0, 0)
    elif str(lb_encoder.inverse_transform(new_pred2)[m-1]) == "pneumonia":
        text = "Pneumonia"
        color = (0, 0, 255)
    img = X_test[m-1].copy()
    # Window name in which image is displayed 
    window_name = text
  
    # font 
    font = cv2.FONT_HERSHEY_SIMPLEX 
  
    # org 
    org = (50, 50) 
  
    # fontScale 
    fontScale = 1
  
    # Line thickness of 2 px 
    thickness = 2
    img = cv2.putText(img, text, org, font,
                      fontScale, color, thickness, cv2.LINE_AA)
    fig.add_subplot(rows, columns, m)
    plt.imshow(img)
    plt.axis('off')
    if m == 1:
        plt.savefig("./Results3.png")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [INFO] Making new prediction...
# [INFO] printing new image with its classification
